# %%
import pandas as pd
import numpy as np
import re
import string

import nltk

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

nltk.download('stopwords')

ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /home/sahil-
# [nltk_data]     gaund/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Text Cleaning Function
def clean_text(text):
    
    text = text.lower()

    text = re.sub(r"http\S+", "", text)

    text = re.sub(r"[^a-zA-Z]", " ", text)

    words = text.split()

    words = [word for word in words if word not in stopwords.words('english')]

    words = [ps.stem(word) for word in words]

    return " ".join(words)

# %%
#apply cleaning 
df = pd.read_csv("/home/sahil-gaund/Desktop/scamshield-ai/datasets/raw/sms_spam.csv", encoding='latin-1')

df = df[['target', 'text']]

df.columns = ['label', 'message']

df['clean_message'] = df['message'].apply(clean_text)

df.head()
# Out:
#   label                                            message  \
# 0  spam  Congratulations! You've been selected for a lu...
# 1  spam  URGENT: Your account has been compromised. Cli...
# 2  spam  You've won a free iPhone! Claim your prize by ...
# 3  spam  Act now and receive a 50% discount on all purc...
# 4  spam  Important notice: Your subscription will expir...
#
#                                        clean_message
# 0  congratul select luxuri vacat getaway claim prize
# 1  urgent account compromis click reset password ...
# 2                  free iphon claim prize click link
# 3       act receiv discount purchas limit time offer
# 4  import notic subscript expir soon renew avoid ...

# %%
# save processed dataset 
df.to_csv("/home/sahil-gaund/Desktop/scamshield-ai/datasets/processed/cleaned_spam.csv", index=False)

print("Processed dataset saved")
# Out:
# Processed dataset saved
